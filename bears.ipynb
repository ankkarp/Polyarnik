# %%
from skimage import img_as_float, io, transform
import os

# %%
#imglist1 = os.listdir('bears')

wb_list = os.listdir('with_bears')
wbmasks_list = os.listdir('wb_masks')
nb_list = os.listdir('arctic_no_bears')

# %%
from PIL import Image, ImageOps

im1 = Image.open('./with_bears/'+ str(wb_list[0]))
im1.show()

# %%
wb = io.imread('./with_bears/0.JPG')
io.imshow(wb)

# %%
for i in range(len(wb_list)):
    #len(wb_list)
    wb = Image.open('./with_bears/'+ str(wb_list[i]))
    #wb = io.imread('./with_bears/'+open(wb_list[i]))
    wb = io.imread('./with_bears/0.JPG')
    for j in range(len(nb_list)):
        #len(nb_list)
        #nb = io.imread(open(nb_list[j]))
        nb = Image.open('./arctic_no_bears/' + str(nb_list[j]))
        changed_background = wb  + nb 
        #* (1- opened[..., None]
        #* opened[..., None]
        changed_background.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       6 for j in range(len(nb_list)):
#       7     #len(nb_list)
#       8     #nb = io.imread(open(nb_list[j]))
#       9     nb = Image.open('./arctic_no_bears/' + str(nb_list[j]))
# ---> 10     changed_background = wb  + nb
#      11     #* (1- opened[..., None]
#      12     #* opened[..., None]
#      13     changed_background.show()
#
# ValueError: operands could not be broadcast together with shapes (2848,4288,3) (4912,7360,3)

# %%
print(len(wb_list))
print(len(nb_list))
# Out:
# 35
# 1000

# %%
#nb = Image.open('./with_bears/'+ str(wb_list[0]))
#io.show(nb)

# %%
import numpy as np

# %%
wbmasks_list = os.listdir('wb_masks')
for i in range(len(wbmasks_list)):
    with Image.open('./wb_masks/'+ str(wbmasks_list[i])) as wb:
        wb_img = np.asarray(wb)
        
        #print(wb_img)

# %%
# 
# dline_med / len(wb_img.shape[0]
# wline_med /

# %%
size_x = [10000, 0]
size_y = [10000, 0]

# %%
#def left(i, j):

# %%
#def right(i, j):

# %%
# def up(i, j):
#     if wb_img[i-1][j] != [0, 0, 0]:
#         left(i-1, j)
#     if wb_img[i+1][j] != [0, 0, 0]:
#         right(i+1, j)

# %%
# def down(i, j):
#     if wb_img[i][j+1] != [0, 0, 0]:
#         down(i, j+1)
#     if wb_img[i-1][j] != [0, 0, 0]:
#         left(i-1, j)
#     if wb_img[i+1][j] != [0, 0, 0]:
#         right(i+1, j)

# %%
# down_hi
# for i in range(len(wb_img.shape[0]))):
#     for j in range(len(wb_img.shape[1]))):
#         if wb_img[i][j] != [0, 0, 0]: 
#             down(i, j)
# Out:
# 255

# %%
color_dict = {}

print('./wb_masks/'+ str(wbmasks_list[34]))
for i in range(wb_img.shape[0]):
    for j in range(wb_img.shape[1]):
        wb_img_list = wb_img[i][j].tolist()
        if wb_img_list != [0, 0, 0]: 
            color_dict[str(wb_img_list)] = []
            
            
for i in range(wb_img.shape[0]):
    for j in range(wb_img.shape[1]):
        wb_img_list = wb_img[i][j].tolist()
        if wb_img_list != [0, 0, 0]: 
            color_dict[str(wb_img_list)].append([i, j])

bear_coordinate_dict = {}
bear_x_y_dict = {}
            
for key in color_dict.keys():
    
    size_y = [10000, 0]
    size_x = [10000, 0]
    bear_x_y_dict[key] = []
    
    for coordinate in color_dict[key]:
        if coordinate[0] > size_y[1]:
            size_y[1] = coordinate[0]
        
        if coordinate[0] < size_y[0]:
            size_y[0] = coordinate[0]
        
        if coordinate[1] > size_x[1]:
            size_x[1] = coordinate[1]
            
        if coordinate[1] < size_x[0]:
            size_x[0] = coordinate[1]
    bear_x_y_dict[key] = [size_x, size_y]

bears_coordinate_list = []
bear_coordinate_dict = {}    

print(bear_x_y_dict)

for key in bear_x_y_dict.keys():
    bear_coordinate_dict = {}
    x_coordinate = bear_x_y_dict[key][0]
    y_coordinate = bear_x_y_dict[key][1]
    
    x = (((x_coordinate[1] - x_coordinate[0]) / 2) + x_coordinate[0]) / wb_img.shape[1]
    y = (((y_coordinate[1] - y_coordinate[0]) / 2) + y_coordinate[0]) / wb_img.shape[0]
    
    x_size = (x_coordinate[1] - x_coordinate[0]) / wb_img.shape[1]
    y_size = (y_coordinate[1] - y_coordinate[0]) / wb_img.shape[0]
    
    bear_coordinate_dict['x'] = x
    bear_coordinate_dict['y'] = y
    bear_coordinate_dict['x_size'] = x_size
    bear_coordinate_dict['y_size'] = y_size
    bears_coordinate_list.append(bear_coordinate_dict)

print(bears_coordinate_list)
# Out:
# ./wb_masks/9.png
# {'[254, 254, 254]': [[2753, 2766], [869, 909]], '[127, 127, 127]': [[2742, 2760], [910, 951]]}
# [{'x': 0.6435401119402985, 'y': 0.3121488764044944, 'x_size': 0.003031716417910448, 'y_size': 0.014044943820224719}, {'x': 0.6415578358208955, 'y': 0.32672050561797755, 'x_size': 0.004197761194029851, 'y_size': 0.014396067415730338}]

# %%
wb_img.shape[0]
# Out:
# 2848

# %%
print(bear_coordinate_dict)
# Out:
# {'[254, 254, 254]': [[2753, 2766], [869, 909]], '[127, 127, 127]': [[2742, 2760], [910, 951]]}

# %%
print(color_dict)
# Out:
# {'[254, 254, 254]': [[869, 2764], [869, 2765], [870, 2762], [870, 2763], [870, 2764], [870, 2765], [870, 2766], [871, 2761], [871, 2762], [871, 2763], [871, 2764], [871, 2765], [871, 2766], [872, 2760], [872, 2761], [872, 2762], [872, 2763], [872, 2764], [872, 2765], [872, 2766], [873, 2759], [873, 2760], [873, 2761], [873, 2762], [873, 2763], [873, 2764], [873, 2765], [873, 2766], [874, 2758], [874, 2759], [874, 2760], [874, 2761], [874, 2762], [874, 2763], [874, 2764], [874, 2765], [874, 2766], [875, 2757], [875, 2758], [875, 2759], [875, 2760], [875, 2761], [875, 2762], [875, 2763], [875, 2764], [875, 2765], [875, 2766], [876, 2756], [876, 2757], [876, 2758], [876, 2759], [876, 2760], [876, 2761], [876, 2762], [876, 2763], [876, 2764], [876, 2765], [876, 2766], [877, 2755], [877, 2756], [877, 2757], [877, 2758], [877, 2759], [877, 2760], [877, 2761], [877, 2762], [877, 2763], [877, 2764], [877, 2765], [877, 2766], [878, 2755], [878, 2756], [878, 2757], [878, 2758], [878, 2759], [8
# ...

# %%
print(color_dict)
# Out:
# {}

# %%
print(wbmasks_list)

# %%
wbmasks_list = os.listdir('./640/masks')
for i in range(len(wbmasks_list)):
    with Image.open('./640/masks/'+ str(wbmasks_list[i])) as wb:
        wb_img = np.asarray(wb)
        color_dict = {}

        print('./640/masks/'+ str(wbmasks_list[i]))
        
        file_name = str(wbmasks_list[i])
        file_name = file_name[:file_name.find('.')]
        file_name = './640/bbox/' + file_name + ".txt"

        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)] = []


        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)].append([i, j])

        bear_coordinate_dict = {}
        bear_x_y_dict = {}

        for key in color_dict.keys():

            size_y = [10000, 0]
            size_x = [10000, 0]
            bear_x_y_dict[key] = []

            for coordinate in color_dict[key]:
                if coordinate[0] > size_y[1]:
                    size_y[1] = coordinate[0]

                if coordinate[0] < size_y[0]:
                    size_y[0] = coordinate[0]

                if coordinate[1] > size_x[1]:
                    size_x[1] = coordinate[1]

                if coordinate[1] < size_x[0]:
                    size_x[0] = coordinate[1]
            bear_x_y_dict[key] = [size_x, size_y]

        bears_coordinate_list = []
        bear_coordinate_dict = {}    

        print(bear_x_y_dict)

        for key in bear_x_y_dict.keys():
            bear_coordinate_dict = {}
            x_coordinate = bear_x_y_dict[key][0]
            y_coordinate = bear_x_y_dict[key][1]

            x = (((x_coordinate[1] - x_coordinate[0]) / 2) + x_coordinate[0]) / wb_img.shape[1]
            y = (((y_coordinate[1] - y_coordinate[0]) / 2) + y_coordinate[0]) / wb_img.shape[0]

            x_size = (x_coordinate[1] - x_coordinate[0]) / wb_img.shape[1]
            y_size = (y_coordinate[1] - y_coordinate[0]) / wb_img.shape[0]

            bear_coordinate_dict['x'] = x
            bear_coordinate_dict['y'] = y
            bear_coordinate_dict['x_size'] = x_size
            bear_coordinate_dict['y_size'] = y_size
            bears_coordinate_list.append(bear_coordinate_dict)

        print(bears_coordinate_list)
        print()        
        print(file_name)
        with open(file_name, 'w') as f:
            for bear_coordinate_dict in bears_coordinate_list:
                f.write("0 {} {} {} {}\n".format(bear_coordinate_dict['x'],
                                               bear_coordinate_dict['y'],
                                               bear_coordinate_dict['x_size'],
                                               bear_coordinate_dict['y_size']))
# Out:
# ./640/masks/0.png
# {'[255, 255, 255]': [[540, 594], [118, 153]]}
# [{'x': 0.8859375, 'y': 0.21171875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./640/bbox/0.txt
# ./640/masks/0_90.png
# {'[255, 255, 255]': [[118, 153], [45, 99]]}
# [{'x': 0.21171875, 'y': 0.1125, 'x_size': 0.0546875, 'y_size': 0.084375}]
#
# ./640/bbox/0_90.txt
# ./640/masks/0_fl.png
# {'[255, 255, 255]': [[540, 594], [486, 521]]}
# [{'x': 0.8859375, 'y': 0.78671875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./640/bbox/0_fl.txt
# ./640/masks/0_fl_90.png
# {'[255, 255, 255]': [[486, 521], [45, 99]]}
# [{'x': 0.78671875, 'y': 0.1125, 'x_size': 0.0546875, 'y_size': 0.084375}]
#
# ./640/bbox/0_fl_90.txt
# ./640/masks/0_mr.png
# {'[255, 255, 255]': [[45, 99], [118, 153]]}
# [{'x': 0.1125, 'y': 0.21171875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./640/bbox/0_mr.txt
# ./640/masks/0_mr_90.png
# {'[255, 255, 255]': [[118, 153], [540, 594]]}
# ...

# %%
for i in range(35):
    os.rename(str(i), "{}.txt".format(str(i)))

# %%
k = 0
l = 0

# %%
# def mr(wb_list, wbmasks_list, folder_name):
#     for i in range(len(wbmasks_list)):
#         mr_bears = Image.open('./{}/bears'.format(folder_name))
#         mr_masks = Image.open('./{}/masks'.format(folder_name))
#         mr_bears = ImageOps.mirror(wb_list(str[i]))
#         mr_masks = ImageOps.mirror(wb_list(str[i]))
#         mr_bears.save('./mirror_horizontal/bears/{}.png'.format(str(k)))
#         mr_masks.save('./mirror_horizontal/masks/{}.png'.format(str(k)))
#         k += 1

def mirror_image(bears_list, masks_list, folder_name):
    for i in range(len(bears_list)):
        filename = str(i) + "_fl.png"
        bear_image = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename))
        mask_image = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename))
        
        bear_image_mirror = ImageOps.mirror(bear_image)
        mask_image_mirror = ImageOps.mirror(mask_image)
        
        bear_image_mirror.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_mr.png"))
        mask_image_mirror.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_mr.png"))

# %%
# def fl(wb_list, wbmasks_list, folder_name):
#     for i in range(len(wbmasks_list)):
#         mr_bears = Image.open('./{}/bears'.format(folder_name))
#         mr_masks = Image.open('./{}/masks'.format(folder_name))
#         mr_bears = ImageOps.flip(wb_list(str[i]))
#         mr_masks = ImageOps.flip(wb_list(str[i]))
#         mr_bears.save('./{}/bears/{}.png'.format(folder_name, str(i+35)))
#         mr_masks.save('./{}/masks/{}.png'.format(folder_name, str(i+35)))
#         l += 1

def flip_image(bears_list, masks_list, folder_name):
    for i in range(int(len(bears_list)/3)):
        filename = str(i) + "_mr.png"
        bear_image = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename))
        mask_image = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename))
        
        bear_image_flip = ImageOps.flip(bear_image)
        mask_image_flip = ImageOps.flip(mask_image)
        
        bear_image_flip.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_fl.png"))
        mask_image_flip.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_fl.png"))

# %%
wb640_list = os.listdir('./640/bears')
wbmasks640_list = os.listdir('./640/masks')

for i in range(len(wb640_list)):
    mirror_image(wb640_list, wbmasks640_list, str(640))
    #flip_image(wb640_list, wbmasks640_list, str(640))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [106], in <cell line: 4>()
#       2 wbmasks640_list = os.listdir('./640/masks')
#       4 for i in range(len(wb640_list)):
# ----> 5     mirror_image(wb640_list, wbmasks640_list, str(640))
#
# Input In [105], in mirror_image(bears_list, masks_list, folder_name)
#      12 for i in range(len(bears_list)):
#      13     filename = str(i) + "_fl.png"
# ---> 14     bear_image = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename))
#      15     mask_image = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename))
#      17     bear_image_mirror = ImageOps.mirror(bear_image)
#
# File C:\Anaconda\lib\site-packages\PIL\Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
# ...

# %%
def rotate90(bears_list, masks_list, folder_name):
    for i in range(35):
        filename = str(i)
        bear = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + ".png"))
        bear_mr = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr.png"))
        bear_fl = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl.png"))
        bear_mr_fl = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl.png"))
        
        mask = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + ".png"))
        mask_mr = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr.png"))
        mask_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl.png"))
        mask_mr_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl.png"))
        
        bear_90 = bear.rotate(90, expand = True)
        bear_mr_90 = bear_mr.rotate(90, expand = True)
        bear_fl_90 = bear_fl.rotate(90, expand = True)
        bear_mr_fl_90 = bear_mr_fl.rotate(90, expand = True)
        
        mask_90 = mask.rotate(90, expand = True)
        mask_mr_90 = mask_mr.rotate(90, expand = True)
        mask_fl_90 = mask_fl.rotate(90, expand = True)
        mask_mr_fl_90 = mask_mr_fl.rotate(90, expand = True)
        
        bear_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_90.png"))
        bear_mr_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_90.png"))
        bear_fl_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl_90.png"))
        bear_mr_fl_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl_90.png"))
        
        mask_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_90.png"))
        mask_mr_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_90.png"))
        mask_fl_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl_90.png"))
        mask_mr_fl_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl_90.png"))
        
#         bear_image = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=str(i)+ ".png"))
#         mask_image = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=str(i)+ ".png"))
        
#         bear_image_mirror = bear_image.rotate(90)
#         mask_image_mirror = mask_image.rotate(90)
        
#         bear_image_mirror.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=str(i) + "_rt.png"))
#         mask_image_mirror.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=str(i) + "_rt.png"))
#         bear_image.close()
#         mask_image.close()

# %%
for i in range(len(wb640_list)):
    rotate90(wb640_list, wbmasks640_list, str(640))

# %%
def rotate180(bears_list, masks_list, folder_name):
    for i in range(35):
        filename = str(i)
        bear = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + ".png"))
        bear_mr = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr.png"))
        bear_fl = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl.png"))
        bear_mr_fl = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl.png"))
        
        mask = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + ".png"))
        mask_mr = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr.png"))
        mask_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl.png"))
        mask_mr_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl.png"))
        
        bear_180 = bear.rotate(180, expand = True)
        bear_mr_180 = bear_mr.rotate(180, expand = True)
        bear_fl_180 = bear_fl.rotate(180, expand = True)
        bear_mr_fl_180 = bear_mr_fl.rotate(180, expand = True)
        
        mask_180 = mask.rotate(180, expand = True)
        mask_mr_180 = mask_mr.rotate(180, expand = True)
        mask_fl_180 = mask_fl.rotate(180, expand = True)
        mask_mr_fl_180 = mask_mr_fl.rotate(180, expand = True)
        
        bear_180.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_180.png"))
        bear_mr_180.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_180.png"))
        bear_fl_180.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl_180.png"))
        bear_mr_fl_180.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl_180.png"))
        
        mask_180.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_180.png"))
        mask_mr_180.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_180.png"))
        mask_fl_180.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl_180.png"))
        mask_mr_fl_180.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl_180.png"))

# %%
for i in range(len(wb640_list)):
    rotate180(wb640_list, wbmasks640_list, str(640))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [123], in <cell line: 1>()
#       1 for i in range(len(wb640_list)):
# ----> 2     rotate180(wb640_list, wbmasks640_list, str(640))
#
# Input In [122], in rotate180(bears_list, masks_list, folder_name)
#      11 mask_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl.png"))
#      12 mask_mr_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_fl.png"))
# ---> 14 bear_180 = bear.rotate(180, expand = True)
#      15 bear_mr_180 = bear_mr.rotate(180, expand = True)
#      16 bear_fl_180 = bear_fl.rotate(180, expand = True)
#
# File C:\Anaconda\lib\site-packages\PIL\Image.py:2057, in Image.rotate(self, angle, resample, expand, center, translate, fillcolor)
#    2055     return self.copy()
#    2056 if angle == 180:
# ...

# %%
bear = Image.open("./640/bears/0.png")
br = bear.rotate(270, expand = True)
br.show()

# %% [markdown]
# # Маркировка аугментированного датасета

# %%
wbmasks_list = os.listdir('./augmented/masks')
for i in range(len(wbmasks_list)):
    with Image.open('./augmented/masks/'+ str(wbmasks_list[i])) as wb:
        wb_img = np.asarray(wb)
        color_dict = {}

        print('./augmented/masks/'+ str(wbmasks_list[i]))
        
        file_name = str(wbmasks_list[i])
        file_name = file_name[:file_name.find('.')]
        file_name = './augmented/bbox/' + file_name + ".txt"

        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)] = []


        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)].append([i, j])

        bear_coordinate_dict = {}
        bear_x_y_dict = {}

        for key in color_dict.keys():

            size_y = [10000, 0]
            size_x = [10000, 0]
            bear_x_y_dict[key] = []

            for coordinate in color_dict[key]:
                if coordinate[0] > size_y[1]:
                    size_y[1] = coordinate[0]

                if coordinate[0] < size_y[0]:
                    size_y[0] = coordinate[0]

                if coordinate[1] > size_x[1]:
                    size_x[1] = coordinate[1]

                if coordinate[1] < size_x[0]:
                    size_x[0] = coordinate[1]
            bear_x_y_dict[key] = [size_x, size_y]

        bears_coordinate_list = []
        bear_coordinate_dict = {}    

        print(bear_x_y_dict)

        for key in bear_x_y_dict.keys():
            bear_coordinate_dict = {}
            x_coordinate = bear_x_y_dict[key][0]
            y_coordinate = bear_x_y_dict[key][1]

            x = (((x_coordinate[1] - x_coordinate[0]) / 2) + x_coordinate[0]) / wb_img.shape[1]
            y = (((y_coordinate[1] - y_coordinate[0]) / 2) + y_coordinate[0]) / wb_img.shape[0]

            x_size = (x_coordinate[1] - x_coordinate[0]) / wb_img.shape[1]
            y_size = (y_coordinate[1] - y_coordinate[0]) / wb_img.shape[0]

            bear_coordinate_dict['x'] = x
            bear_coordinate_dict['y'] = y
            bear_coordinate_dict['x_size'] = x_size
            bear_coordinate_dict['y_size'] = y_size
            bears_coordinate_list.append(bear_coordinate_dict)

        print(bears_coordinate_list)
        print()        
        print(file_name)
        with open(file_name, 'w') as f:
            for bear_coordinate_dict in bears_coordinate_list:
                f.write("0 {} {} {} {}\n".format(bear_coordinate_dict['x'],
                                               bear_coordinate_dict['y'],
                                               bear_coordinate_dict['x_size'],
                                               bear_coordinate_dict['y_size']))
# Out:
# ./augmented/masks/0.PNG
# {'[255, 255, 255]': [[540, 594], [118, 153]]}
# [{'x': 0.8859375, 'y': 0.21171875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./augmented/bbox/0.txt
# ./augmented/masks/1.PNG
# {'[85, 85, 85]': [[0, 49], [267, 291]], '[170, 170, 170]': [[0, 3], [282, 296]]}
# [{'x': 0.03828125, 'y': 0.4359375, 'x_size': 0.0765625, 'y_size': 0.0375}, {'x': 0.00234375, 'y': 0.4515625, 'x_size': 0.0046875, 'y_size': 0.021875}]
#
# ./augmented/bbox/1.txt
# ./augmented/masks/10.PNG
# {'[255, 255, 255]': [[391, 434], [0, 54]]}
# [{'x': 0.64453125, 'y': 0.0421875, 'x_size': 0.0671875, 'y_size': 0.084375}]
#
# ./augmented/bbox/10.txt
# ./augmented/masks/100.PNG
# {'[255, 255, 255]': [[383, 416], [164, 203]]}
# [{'x': 0.62421875, 'y': 0.17117537313432835, 'x_size': 0.0515625, 'y_size': 0.036380597014925374}]
#
# ./augmented/bbox/100.txt
# ./augmented/masks/1000.PNG
# ...

# %% [markdown]
# # Расширения аугментированного датасета

# %%
def flip_image_aug(bears_list, masks_list, folder_name):
    for i in range(len(bears_list)):
        filename = str(i) + ".png"
        bear_image = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename))
        mask_image = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename))
        
        bear_image_flip = ImageOps.flip(bear_image)
        mask_image_flip = ImageOps.flip(mask_image)
        
        bear_image_flip.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_fl.png"))
        mask_image_flip.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_fl.png"))

# %%
def mirror_image_aug(bears_list, masks_list, folder_name):
    for i in range(len(bears_list)):
        filename = str(i) + ".png"
        bear_image = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename))
        mask_image = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename))
        
        bear_image_mirror = ImageOps.mirror(bear_image)
        mask_image_mirror = ImageOps.mirror(mask_image)
        
        bear_image_mirror.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_mr.png"))
        mask_image_mirror.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename.split(".")[0] + "_mr.png"))

# %%
bears_aug_list = os.listdir('./augmented/bears')
masks_aug_list = os.listdir('./augmented/masks')

augmented = "augmented"

for i in range(len(bears_aug_list)):
    mirror_image_aug(bears_aug_list, masks_aug_list, str(augmented))
    flip_image_aug(bears_aug_list, masks_aug_list, str(augmented))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File C:\Anaconda\lib\site-packages\PIL\ImageFile.py:495, in _save(im, fp, tile, bufsize)
#     494 try:
# --> 495     fh = fp.fileno()
#     496     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [141], in <cell line: 6>()
#       6 for i in range(len(bears_aug_list)):
#       7     mirror_image_aug(bears_aug_list, masks_aug_list, str(augmented))
# ----> 8     flip_image_aug(bears_aug_list, masks_aug_list, str(augmented))
#
# Input In [139], in flip_image_aug(bears_list, masks_list, folder_name)
#       7 bear_image_flip = ImageOps.flip(bear_image)
#       8 mask_image_flip = ImageOps.flip(mask_image)
# ...

# %%
wbmasks_list = os.listdir('./augmented/masks')
for i in range(len(wbmasks_list)):
    with Image.open('./augmented/masks/'+ str(wbmasks_list[i])) as wb:
        wb_img = np.asarray(wb)
        color_dict = {}

        print('./augmented/masks/'+ str(wbmasks_list[i]))
        
        file_name = str(wbmasks_list[i])
        file_name = file_name[:file_name.find('.')]
        file_name = './augmented/bbox/' + file_name + ".txt"

        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)] = []


        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)].append([i, j])

        bear_coordinate_dict = {}
        bear_x_y_dict = {}

        for key in color_dict.keys():

            size_y = [10000, 0]
            size_x = [10000, 0]
            bear_x_y_dict[key] = []

            for coordinate in color_dict[key]:
                if coordinate[0] > size_y[1]:
                    size_y[1] = coordinate[0]

                if coordinate[0] < size_y[0]:
                    size_y[0] = coordinate[0]

                if coordinate[1] > size_x[1]:
                    size_x[1] = coordinate[1]

                if coordinate[1] < size_x[0]:
                    size_x[0] = coordinate[1]
            bear_x_y_dict[key] = [size_x, size_y]

        bears_coordinate_list = []
        bear_coordinate_dict = {}    

        print(bear_x_y_dict)

        for key in bear_x_y_dict.keys():
            bear_coordinate_dict = {}
            x_coordinate = bear_x_y_dict[key][0]
            y_coordinate = bear_x_y_dict[key][1]

            x = (((x_coordinate[1] - x_coordinate[0]) / 2) + x_coordinate[0]) / wb_img.shape[1]
            y = (((y_coordinate[1] - y_coordinate[0]) / 2) + y_coordinate[0]) / wb_img.shape[0]

            x_size = (x_coordinate[1] - x_coordinate[0]) / wb_img.shape[1]
            y_size = (y_coordinate[1] - y_coordinate[0]) / wb_img.shape[0]

            bear_coordinate_dict['x'] = x
            bear_coordinate_dict['y'] = y
            bear_coordinate_dict['x_size'] = x_size
            bear_coordinate_dict['y_size'] = y_size
            bears_coordinate_list.append(bear_coordinate_dict)

        print(bears_coordinate_list)
        print()        
        print(file_name)
        with open(file_name, 'w') as f:
            for bear_coordinate_dict in bears_coordinate_list:
                f.write("0 {} {} {} {}\n".format(bear_coordinate_dict['x'],
                                               bear_coordinate_dict['y'],
                                               bear_coordinate_dict['x_size'],
                                               bear_coordinate_dict['y_size']))
# Out:
# ./augmented/masks/0.PNG
# {'[255, 255, 255]': [[540, 594], [118, 153]]}
# [{'x': 0.8859375, 'y': 0.21171875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./augmented/bbox/0.txt
# ./augmented/masks/0_fl.png
# {'[255, 255, 255]': [[540, 594], [486, 521]]}
# [{'x': 0.8859375, 'y': 0.78671875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./augmented/bbox/0_fl.txt
# ./augmented/masks/0_mr.png
# {'[255, 255, 255]': [[45, 99], [118, 153]]}
# [{'x': 0.1125, 'y': 0.21171875, 'x_size': 0.084375, 'y_size': 0.0546875}]
#
# ./augmented/bbox/0_mr.txt
# ./augmented/masks/1.PNG
# {'[85, 85, 85]': [[0, 49], [267, 291]], '[170, 170, 170]': [[0, 3], [282, 296]]}
# [{'x': 0.03828125, 'y': 0.4359375, 'x_size': 0.0765625, 'y_size': 0.0375}, {'x': 0.00234375, 'y': 0.4515625, 'x_size': 0.0046875, 'y_size': 0.021875}]
#
# ./augmented/bbox/1.txt
# ./augmented/masks/10.PNG
# {'[255, 255, 255]': [[391, 434], [0, 54]]}
# [{'x': 0.64453125, 'y': 0.0421875, 'x_size': 0.0671875, 'y_size': 0.084375}]
#
# ...

# %% [markdown]
# # Расширение 8К фото

# %%
bears_list = os.listdir('./8K/bears')
masks_list = os.listdir('./8K/masks')

# %%
def mirror_8K_image(bears_list, masks_list, folder_name):
    for i in range(len(bears_list)):
        bear_image = Image.open('./{folder}/bears/'.format(folder=folder_name)+ str(i) + '.JPG')
        mask_image = Image.open('./{folder}/masks/'.format(folder=folder_name)+ str(i) + '.png')
        
        bear_image_mirror = ImageOps.mirror(bear_image)
        mask_image_mirror = ImageOps.mirror(mask_image)
        
        bear_image_mirror.save('./{folder}/bears/'.format(folder=folder_name) + str(i) + "_mr.JPG")
        mask_image_mirror.save('./{folder}/masks/'.format(folder=folder_name) + str(i) + "_mr.png")
        bear_image.close()
        mask_image.close()

# %%
def flip_8K_image(bears_list, masks_list, folder_name):
    for i in range(len(bears_list)):
        bear_image = Image.open('./{folder}/bears/'.format(folder=folder_name)+ str(i) + '.JPG')
        mask_image = Image.open('./{folder}/masks/'.format(folder=folder_name)+ str(i) + '.png')
        
        bear_image_flip = ImageOps.flip(bear_image)
        mask_image_flip = ImageOps.flip(mask_image)
        
        bear_image_flip.save('./{folder}/bears/'.format(folder=folder_name) + str(i) + "_fl.JPG")
        mask_image_flip.save('./{folder}/masks/'.format(folder=folder_name) + str(i) +  "_fl.png")
        bear_image.close()
        mask_image.close()

# %%
def mirror_to_flip_image(bears_list, masks_list, folder_name):
    for i in range(len(bears_list)):
        bear_image = Image.open('./{folder}/bears/'.format(folder=folder_name)+ str(i) + '_fl.JPG')
        mask_image = Image.open('./{folder}/masks/'.format(folder=folder_name)+ str(i) + '_fl.png')
        
        bear_image_mirror = ImageOps.mirror(bear_image)
        mask_image_mirror = ImageOps.mirror(mask_image)
        
        bear_image_mirror.save('./{folder}/bears/'.format(folder=folder_name) + str(i) + "_fl_mr.JPG")
        mask_image_mirror.save('./{folder}/masks/'.format(folder=folder_name) + str(i) + "_fl_mr.png")
        bear_image.close()
        mask_image.close()

# %%
image_8K_str = '8K'

for i in range(len(bears_list)):
    #mirror_8K_image(bears_list, masks_list, str(image_8K_str))
    flip_8K_image(bears_list, masks_list, str(image_8K_str))
    #mirror_to_flip_image(bears_list, masks_list, str(image_8K_str))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [189], in <cell line: 3>()
#       1 image_8K_str = '8K'
#       3 for i in range(len(bears_list)):
#       4     #mirror_8K_image(bears_list, masks_list, str(image_8K_str))
# ----> 5     flip_8K_image(bears_list, masks_list, str(image_8K_str))
#
# Input In [188], in flip_8K_image(bears_list, masks_list, folder_name)
#       3 bear_image = Image.open('./{folder}/bears/'.format(folder=folder_name)+ str(i) + '.JPG')
#       4 mask_image = Image.open('./{folder}/masks/'.format(folder=folder_name)+ str(i) + '.png')
# ----> 6 bear_image_flip = ImageOps.flip(bear_image)
#       7 mask_image_flip = ImageOps.flip(mask_image)
#       9 bear_image_flip.save('./{folder}/bears/'.format(folder=folder_name) + str(i) + "_fl.JPG")
#
# File C:\Anaconda\lib\site-packages\PIL\ImageOps.py:503, in flip(image)
#     496 def flip(image):
# ...

# %%
masks_list = os.listdir('./8K/masks')

# %%
def rotate90_8K(bears_list, masks_list, folder_name):
    for i in range(35):
        filename = str(i)
        bear = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + ".JPG"))
        bear_mr = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr.JPG"))
        bear_fl = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl.JPG"))
        bear_mr_fl = Image.open('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl_mr.JPG"))
        
        mask = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + ".png"))
        mask_mr = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr.png"))
        mask_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl.png"))
        mask_mr_fl = Image.open('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl_mr.png"))
        
        bear_90 = bear.rotate(90, expand = True)
        bear_mr_90 = bear_mr.rotate(90, expand = True)
        bear_fl_90 = bear_fl.rotate(90, expand = True)
        bear_mr_fl_90 = bear_mr_fl.rotate(90, expand = True)
        
        mask_90 = mask.rotate(90, expand = True)
        mask_mr_90 = mask_mr.rotate(90, expand = True)
        mask_fl_90 = mask_fl.rotate(90, expand = True)
        mask_mr_fl_90 = mask_mr_fl.rotate(90, expand = True)
        
        print('./8K/masks/'+ str(masks_list[i]))
        
        bear_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_90.JPG"))
        bear_mr_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_mr_90.JPG"))
        bear_fl_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl_90.JPG"))
        bear_mr_fl_90.save('./{folder}/bears/{filename}'.format(folder=folder_name, filename=filename + "_fl_mr_90.JPG"))
        
        mask_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_90.png"))
        mask_mr_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_mr_90.png"))
        mask_fl_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl_90.png"))
        mask_mr_fl_90.save('./{folder}/masks/{filename}'.format(folder=folder_name, filename=filename + "_fl_mr_90.png"))

# %%
for i in range(len(bears_list)):
    rotate90_8K(bears_list, masks_list, str(image_8K_str))
# Out:
# ./8K/masks/0.png
# ./8K/masks/0_fl.png
# ./8K/masks/0_fl_mr.png
# ./8K/masks/0_mr.png
# ./8K/masks/1.png
# ./8K/masks/10.png
# ./8K/masks/10_fl.png
# ./8K/masks/10_fl_mr.png
# ./8K/masks/10_mr.png
# ./8K/masks/11.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [197], in <cell line: 1>()
#       1 for i in range(len(bears_list)):
# ----> 2     rotate90_8K(bears_list, masks_list, str(image_8K_str))
#
# Input In [195], in rotate90_8K(bears_list, masks_list, folder_name)
#      16 bear_fl_90 = bear_fl.rotate(90, expand = True)
#      17 bear_mr_fl_90 = bear_mr_fl.rotate(90, expand = True)
# ---> 19 mask_90 = mask.rotate(90, expand = True)
#      20 mask_mr_90 = mask_mr.rotate(90, expand = True)
#      21 mask_fl_90 = mask_fl.rotate(90, expand = True)
#
# ...

# %% [markdown]
# # Маркировка 8К фото

# %%
wbmasks_list = os.listdir('./8K/masks')
for i in range(len(wbmasks_list)):
    with Image.open('./8K/masks/'+ str(wbmasks_list[i])) as wb:
        wb_img = np.asarray(wb)
        color_dict = {}

        print('./8K/masks/'+ str(wbmasks_list[i]))
        
        file_name = str(wbmasks_list[i])
        file_name = file_name[:file_name.find('.')]
        file_name = './8K/bbox/' + file_name + ".txt"

        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)] = []


        for i in range(wb_img.shape[0]):
            for j in range(wb_img.shape[1]):
                wb_img_list = wb_img[i][j].tolist()
                if wb_img_list != [0, 0, 0]: 
                    color_dict[str(wb_img_list)].append([i, j])

        bear_coordinate_dict = {}
        bear_x_y_dict = {}

        for key in color_dict.keys():

            size_y = [10000, 0]
            size_x = [10000, 0]
            bear_x_y_dict[key] = []

            for coordinate in color_dict[key]:
                if coordinate[0] > size_y[1]:
                    size_y[1] = coordinate[0]

                if coordinate[0] < size_y[0]:
                    size_y[0] = coordinate[0]

                if coordinate[1] > size_x[1]:
                    size_x[1] = coordinate[1]

                if coordinate[1] < size_x[0]:
                    size_x[0] = coordinate[1]
            bear_x_y_dict[key] = [size_x, size_y]

        bears_coordinate_list = []
        bear_coordinate_dict = {}    

        print(bear_x_y_dict)

        for key in bear_x_y_dict.keys():
            bear_coordinate_dict = {}
            x_coordinate = bear_x_y_dict[key][0]
            y_coordinate = bear_x_y_dict[key][1]

            x = (((x_coordinate[1] - x_coordinate[0]) / 2) + x_coordinate[0]) / wb_img.shape[1]
            y = (((y_coordinate[1] - y_coordinate[0]) / 2) + y_coordinate[0]) / wb_img.shape[0]

            x_size = (x_coordinate[1] - x_coordinate[0]) / wb_img.shape[1]
            y_size = (y_coordinate[1] - y_coordinate[0]) / wb_img.shape[0]

            bear_coordinate_dict['x'] = x
            bear_coordinate_dict['y'] = y
            bear_coordinate_dict['x_size'] = x_size
            bear_coordinate_dict['y_size'] = y_size
            bears_coordinate_list.append(bear_coordinate_dict)

        print(bears_coordinate_list)
        print()        
        print(file_name)
        with open(file_name, 'w') as f:
            for bear_coordinate_dict in bears_coordinate_list:
                f.write("0 {} {} {} {}\n".format(bear_coordinate_dict['x'],
                                               bear_coordinate_dict['y'],
                                               bear_coordinate_dict['x_size'],
                                               bear_coordinate_dict['y_size']))
# Out:
# ./8K/masks/0.png
# {'[255, 255, 255]': [[2460, 2514], [118, 153]]}
# [{'x': 0.5799906716417911, 'y': 0.04757724719101124, 'x_size': 0.012593283582089552, 'y_size': 0.01228932584269663}]
#
# ./8K/bbox/0.txt
# ./8K/masks/0_90.png
# {'[255, 255, 255]': [[118, 153], [1773, 1827]]}
# [{'x': 0.04757724719101124, 'y': 0.4197761194029851, 'x_size': 0.01228932584269663, 'y_size': 0.012593283582089552}]
#
# ./8K/bbox/0_90.txt
# ./8K/masks/0_fl.png
# {'[255, 255, 255]': [[2460, 2514], [2694, 2729]]}
# [{'x': 0.5799906716417911, 'y': 0.9520716292134831, 'x_size': 0.012593283582089552, 'y_size': 0.01228932584269663}]
#
# ./8K/bbox/0_fl.txt
# ./8K/masks/0_fl_90.png
# {'[255, 255, 255]': [[2694, 2729], [1773, 1827]]}
# [{'x': 0.9520716292134831, 'y': 0.4197761194029851, 'x_size': 0.01228932584269663, 'y_size': 0.012593283582089552}]
#
# ./8K/bbox/0_fl_90.txt
# ./8K/masks/0_fl_mr.png
# {'[255, 255, 255]': [[1773, 1827], [2694, 2729]]}
# ...
